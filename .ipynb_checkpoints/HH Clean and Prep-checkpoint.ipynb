# %% [markdown]
# # Convert IPUMS data into something Tableau can swallow

# %%
#imports
import os
import pandas as pd
import numpy as np

# %%
#get data
mydir = os.getcwd()
fulldata = pd.read_csv(os.path.join(mydir,'hhdatasmall.csv'))

# %%
#initialize zeros array
counter = fulldata.nunique()
output = np.zeros([counter[2],6])

# %%
currSerial = 0
grpAge = np.zeros(20)
grpEmp = np.zeros(20)
j = 0
init=True
working = True
for i in range(len(fulldata)):
    if fulldata["SERIAL"][i] > currSerial:
        if init:
            k=0
            currSerial = fulldata["SERIAL"][i]
            grpAge = np.zeros(20)
            grpEmp = np.zeros(20)
            grpAge[k] = fulldata["AGE"][i]
            grpEmp[k] = fulldata["EMPSTAT"][i]
            k+=1
            init = False
        else:
            #test if household has child under 18
            if grpAge.min()<18:
                U18 = True
            else:
                U18 = False
            
            #test for working people in household
            #grpAgeTest = grpAge - 1
            #numWorking = len(grpAgeTest) - len(np.count_nonzero(grpAgeTest)
            #if numWorking>0:
            #    working = True
            #else:
            #    working = False
            
            #take down values
            output[j][0] = fulldata["YEAR"][i-1]
            output[j][1] = fulldata["HHWT"][i-1]
            output[j][2] = fulldata["STATEFIP"][i-1]
            output[j][3] = fulldata["POVERTY"][i-1]
            output[j][4] = U18
            output[j][5] = working
            
            #reset counter
            k=0
            currSerial = fulldata["SERIAL"][i]
            grpAge = np.zeros(20)
            grpEmp = np.zeros(20)
            grpAge[k] = fulldata["AGE"][i]
            grpEmp[k] = fulldata["EMPSTAT"][i]
            k+=1
    else:
        grpAge[k] = fulldata["AGE"][i]
        grpEmp[k] = fulldata["EMPSTAT"][i]
        k+=1

# %%
output
# Out:
# array([[  2.00700000e+03,   1.10000000e+02,   1.00000000e+00,
#           4.69000000e+02,   1.00000000e+00,   1.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
range(93)
# Out:
# range(0, 93)

# %%
fulldata
# Out:
#     YEAR  DATANUM  SERIAL  HHWT  STATEFIP  GQ  HHINCOME  PERNUM  PERWT  AGE  \
# 0   2007        1       4    88         1   1     46300       1     87   33
# 1   2007        1       4    88         1   1     46300       2     66   25
# 2   2007        1       4    88         1   1     46300       3     69    9
# 3   2007        1       4    88         1   1     46300       4     70    7
# 4   2007        1       4    88         1   1     46300       5     72    2
# 5   2007        1       6    89         1   1    154400       1     94   58
# 6   2007        1       6    89         1   1    154400       2     67   56
# 7   2007        1       6    89         1   1    154400       3    117   27
# 8   2007        1       6    89         1   1    154400       4     97    9
# 9   2007        1       7    62         1   1    126000       1     63   39
# 10  2007        1       7    62         1   1    126000       2     76   41
# 11  2007        1       7    62         1   1    126000       3     63   10
# 12  2007        1       7    62         1   1    126000       4     61    8
# 13  2007        1       8    24         1   1     82000       1     25   46
# 14  2007        1       8    24         1   1     82000       2     25   35
# 15  2007        1      12   249         1   1      1770       1    250   21
# 16  2007        1      12   249         1   1      1770       2    147    3
# 17  2007        1      12   249         1   1      1770       3    324    0
# 18  2007        1      14    64         1   1    115620       1     65   30
# 19  2007        1      14    64         1   1    115620       2     71   30
# 20  2007        1      14    64         1   1    115620       3     75    6
# 21  2007        1      14    64         1   1    115620       4    100    3
# 22  2007        1      16    56         1   1     75380       1     57   78
# 23  2007        1      16    56         1   1     75380       2    109   43
# 24  2007        1      16    56         1   1     75380       3    108   41
# 25  2007        1      16    56         1   1     75380       4    109   21
# 26  2007        1      16    56         1   1     75380       5     45   18
# 27  2007        1      16    56         1   1     75380       6     28   13
# 28  2007        1      16    56         1   1     75380       7     73   48
# 29  2007        1      18    27         1   1     45400       1     27   56
# ..   ...      ...     ...   ...       ...  ..       ...     ...    ...  ...
# 63  2007        1      34    16         1   1     30000       1     16   23
# 64  2007        1      35    63         1   1     45700       1     63   68
# 65  2007        1      35    63         1   1     45700       2     76   50
# 66  2007        1      37    83         1   1     88700       1     86   67
# 67  2007        1      37    83         1   1     88700       2    100   67
# 68  2007        1      37    83         1   1     88700       3    181   42
# 69  2007        1      38    19         1   1    107230       1     18   63
# 70  2007        1      38    19         1   1    107230       2     21   55
# 71  2007        1      38    19         1   1    107230       3     27   85
# 72  2007        1      40    67         1   1     60500       1     67   40
# 73  2007        1      40    67         1   1     60500       2     78   40
# 74  2007        1      40    67         1   1     60500       3     66   14
# 75  2007        1      40    67         1   1     60500       4     69   12
# 76  2007        1      40    67         1   1     60500       5     67   10
# 77  2007        1      40    67         1   1     60500       6     68    8
# 78  2007        1      41   122         1   1     19210       1    122   34
# 79  2007        1      41   122         1   1     19210       2     72   58
# 80  2007        1      42    86         1   1     82100       1     85   76
# 81  2007        1      42    86         1   1     82100       2    107   72
# 82  2007        1      42    86         1   1     82100       3     85   33
# 83  2007        1      42    86         1   1     82100       4     91   14
# 84  2007        1      42    86         1   1     82100       5     88   12
# 85  2007        1      47    61         1   1     70600       1     61   32
# 86  2007        1      47    61         1   1     70600       2     39   29
# 87  2007        1      48    79         1   1     26100       1     76   21
# 88  2007        1      48    79         1   1     26100       2     80   36
# 89  2007        1      48    79         1   1     26100       3     71   12
# 90  2007        1      49   110         1   1     50000       1    107   31
# 91  2007        1      50    97         1   1     45900       1    100   57
# 92  2007        1      50    97         1   1     45900       2    143   68
#
#     EMPSTAT  EMPSTATD  POVERTY
# 0         1        10      189
# 1         3        30      189
# 2         0         0      189
# 3         0         0      189
# 4         0         0      189
# 5         1        10      501
# 6         1        10      501
# 7         1        10      501
# 8         0         0      501
# 9         1        10      501
# 10        1        10      501
# 11        0         0      501
# 12        0         0      501
# 13        1        10      252
# 14        1        10      501
# 15        1        10       10
# 16        0         0       10
# 17        0         0       10
# 18        1        10      501
# 19        1        10      501
# 20        0         0      501
# 21        0         0      501
# 22        3        30      223
# 23        3        30      223
# 24        1        10      223
# 25        1        10      223
# 26        3        30      223
# 27        0         0      223
# 28        1        10      223
# 29        1        10      423
# ..      ...       ...      ...
# 63        1        10      283
# 64        3        30      369
# 65        1        10      369
# 66        1        10      501
# 67        1        10      501
# 68        1        10      501
# 69        3        30      501
# 70        1        10      501
# 71        3        30      501
# 72        1        10      221
# 73        3        30      221
# 74        0         0      221
# 75        0         0      221
# 76        0         0      221
# 77        0         0      221
# 78        1        10      139
# 79        3        30      139
# 80        1        10      333
# 81        3        30      333
# 82        1        10      333
# 83        0         0      333
# 84        0         0      333
# 85        1        10      501
# 86        1        10      501
# 87        1        10      159
# 88        2        20      159
# 89        0         0      159
# 90        1        10      469
# 91        1        10      337
# 92        1        10      337
#
# [93 rows x 13 columns]
